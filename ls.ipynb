# %%
import pandas as pd
df = pd.read_csv('/Users/samikshaburkul/Desktop/Datawarehousing project/Liquor_Sales.csv')
print(df.dtypes)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/samikshaburkul/Downloads/ls.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/Users/samikshaburkul/Downloads/ls.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/Users/samikshaburkul/Downloads/ls.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> df = pd.read_csv('/Users/samikshaburkul/Desktop/Datawarehousing project/Liquor_Sales.csv')
#       <a href='vscode-notebook-cell:/Users/samikshaburkul/Downloads/ls.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> print(df.dtypes)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df.dropna(inplace=True)
df.columns = ['invoice_number','date','store_number','store_name','address','city','zip_code','store_location','county_number','county','category','category_name','vendor_number','vendor_name', 'item_number','item_description','pack','bottle_volume_ml','state_bottle_cost','state_bottle_retail','bottles_sold','sale_usd','volume_sold_liters','volume_sold_gallons']
df.drop('item_number', axis=1, inplace=True)
df['date'] = pd.to_datetime(df['date'], format='%m/%d/%Y').dt.strftime('%Y-%m-%d')
df['store_number'] = df['store_number'].astype(int)
df['county_number'] = df['county_number'].astype(int)
df['category'] = df['category'].astype(int)
df['vendor_number'] = df['vendor_number'].astype(int)
df['pack'] = df['pack'].astype(int)
df['bottle_volume_ml'] = df['bottle_volume_ml'].astype(int)
df['bottles_sold'] = df['bottles_sold'].astype(int)
df.head()
# Out:
#   invoice_number        date  store_number  \
# 0   S24127700024  2015-02-19          3678
# 1   S15066200002  2013-10-10          2633
# 2   S19323500030  2014-06-03          2607
# 3   S23334500013  2015-01-06          4810
# 4   S09742200010  2012-12-27          4025
#
#                              store_name                   address  \
# 0                       Smoke Shop, The           1918 SE 14TH ST
# 1          Hy-Vee #3 / BDI / Des Moines           3221 SE 14TH ST
# 2  Hy-Vee Wine and Spirits / Shenandoah            520 SO FREMONT
# 3                Kum & Go #518 / Ankeny  3603 NE OTTERVIEW CIRCLE
# 4               Karam Kaur Khasriya Llc               702 13TH ST
#
#            city zip_code                store_location  county_number  county  \
# 0    DES MOINES    50320  POINT (-93.597011 41.570844)             77    Polk
# 1    DES MOINES    50320  POINT (-93.596754 41.554101)             77    Polk
# ...

# %%
df.to_csv('liquor_sales_updated.csv', index=False)

# %%
dff = pd.read_csv('/Users/krishnasurya/Downloads/liquor_sales_updated.csv')
dff.dtypes
# Out:
# /var/folders/5f/7v8mj7yn1kv22ww3m91nt6_00000gn/T/ipykernel_48546/113598518.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   dff = pd.read_csv('/Users/krishnasurya/Downloads/liquor_sales_updated.csv')
# invoice_number          object
# date                    object
# store_number             int64
# store_name              object
# address                 object
# city                    object
# zip_code                object
# store_location          object
# county_number            int64
# county                  object
# category                 int64
# category_name           object
# vendor_number            int64
# vendor_name             object
# item_description        object
# pack                     int64
# bottle_volume_ml         int64
# state_bottle_cost      float64
# state_bottle_retail    float64
# bottles_sold             int64
# sale_usd               float64
# volume_sold_liters     float64
# ...
